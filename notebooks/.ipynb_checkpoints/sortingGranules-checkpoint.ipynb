# %%
import numpy as np
import os
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# #### For RiverSP

# %%
data_path = '/nas/cee-water/cjgleason/data/SWOT/RiverSP_v2_0_20240624/GR/Reach/'

# %%
# Get all filenames in directory
files = []
for file in os.listdir(data_path):
    # will deal with other four types later
    if file.endswith(".shp"):
        files.append(os.path.join(file))

# %%
# Make DataFrame of filenames
granules = pd.DataFrame({'files': files})

# %%
granules['cycle'] = granules['files'].str.slice(25,28)
granules['pass'] = granules['files'].str.slice(29,32)
granules['version'] = granules['files'].str.slice(-11,-7)
granules['counter'] = granules['files'].str.slice(-6,-4)
# granules['date_0'] = granules['files'].str.slice(36,44) # don't think we need this bc cycle captures

# %%
granules
# Out:
#                                                                                 files  \
# 0     SWOT_L2_HR_RiverSP_Reach_476_009_GR_20230331T051911_20230331T051922_PGC0_01.shp
# 1     SWOT_L2_HR_RiverSP_Reach_476_016_GR_20230331T103031_20230331T103037_PGC0_01.shp
# 2     SWOT_L2_HR_RiverSP_Reach_478_009_GR_20230402T050027_20230402T050038_PGC0_01.shp
# 3     SWOT_L2_HR_RiverSP_Reach_478_016_GR_20230402T101147_20230402T101152_PGC0_01.shp
# 4     SWOT_L2_HR_RiverSP_Reach_479_009_GR_20230403T045104_20230403T045106_PGC0_01.shp
# ...                                                                               ...
# 1569  SWOT_L2_HR_RiverSP_Reach_017_038_GR_20240620T091836_20240620T091848_PIC0_01.shp
# 1570  SWOT_L2_HR_RiverSP_Reach_017_039_GR_20240620T110004_20240620T110010_PIC0_01.shp
# 1571  SWOT_L2_HR_RiverSP_Reach_017_040_GR_20240620T110253_20240620T110302_PIC0_01.shp
# 1572  SWOT_L2_HR_RiverSP_Reach_017_042_GR_20240620T124434_20240620T124435_PIC0_01.shp
# 1573  SWOT_L2_HR_RiverSP_Reach_017_044_GR_20240620T143042_20240620T143049_PIC0_01.shp
#
#      cycle pass version counter
# 0      476  009    PGC0      01
# 1      476  016    PGC0      01
# 2      478  009    PGC0      01
# 3      478  016    PGC0      01
# 4      479  009    PGC0      01
# ...    ...  ...     ...     ...
# 1569   017  038    PIC0      01
# 1570   017  039    PIC0      01
# 1571   017  040    PIC0      01
# 1572   017  042    PIC0      01
# 1573   017  044    PIC0      01
#
# [1574 rows x 5 columns]

# %%
dupe = granules[granules.duplicated(['cycle', 'pass'])]

# %%
dupe
# Out:
#                                                                                 files  \
# 115   SWOT_L2_HR_RiverSP_Reach_001_229_GR_20230729T094809_20230729T094818_PGC0_02.shp
# 132   SWOT_L2_HR_RiverSP_Reach_001_292_GR_20230731T150755_20230731T150804_PGC0_02.shp
# 346   SWOT_L2_HR_RiverSP_Reach_004_484_GR_20231009T015814_20231009T015817_PGC0_02.shp
# 354   SWOT_L2_HR_RiverSP_Reach_004_511_GR_20231010T015628_20231010T015636_PGC0_02.shp
# 678   SWOT_L2_HR_RiverSP_Reach_010_007_GR_20240125T061336_20240125T061339_PIC0_02.shp
# 680   SWOT_L2_HR_RiverSP_Reach_010_009_GR_20240125T075948_20240125T075953_PIC0_02.shp
# 682   SWOT_L2_HR_RiverSP_Reach_010_010_GR_20240125T080233_20240125T080236_PIC0_02.shp
# 684   SWOT_L2_HR_RiverSP_Reach_010_011_GR_20240125T094354_20240125T094357_PIC0_02.shp
# 686   SWOT_L2_HR_RiverSP_Reach_010_012_GR_20240125T094631_20240125T094639_PIC0_02.shp
# 688   SWOT_L2_HR_RiverSP_Reach_010_014_GR_20240125T112821_20240125T112832_PIC0_02.shp
# 690   SWOT_L2_HR_RiverSP_Reach_010_016_GR_20240125T131418_20240125T131426_PIC0_02.shp
# 1250  SWOT_L2_HR_RiverSP_Reach_014_512_GR_20240505T172943_20240505T172946_PIC0_02.shp
# 1290  SWOT_L2_HR_RiverSP_Reach_015_070_GR_20240510T191507_20240510T191516_PIC0_01.shp
# 1292  SWOT_L2_HR_RiverSP_Reach_015_072_GR_20240510T210127_20240510T210130_PIC0_02.shp
#
#      cycle pass version counter
# 115    001  229    PGC0      02
# 132    001  292    PGC0      02
# 346    004  484    PGC0      02
# 354    004  511    PGC0      02
# 678    010  007    PIC0      02
# 680    010  009    PIC0      02
# 682    010  010    PIC0      02
# 684    010  011    PIC0      02
# 686    010  012    PIC0      02
# 688    010  014    PIC0      02
# 690    010  016    PIC0      02
# 1250   014  512    PIC0      02
# 1290   015  070    PIC0      01
# 1292   015  072    PIC0      02

# %%
# Example with two version of PGC0, _01 comes first
granules[(granules['cycle'] == '001') & (granules['pass'] == '229')]
# Out:
#                                                                                files  \
# 114  SWOT_L2_HR_RiverSP_Reach_001_229_GR_20230729T094809_20230729T094818_PGC0_01.shp
# 115  SWOT_L2_HR_RiverSP_Reach_001_229_GR_20230729T094809_20230729T094818_PGC0_02.shp
#
#     cycle pass version counter
# 114   001  229    PGC0      01
# 115   001  229    PGC0      02

# %%
# Sort the files
granules = granules.sort_values(by=['cycle', 'pass', 'version', 'counter'],
                                ascending=[True, True, True, False])

# %%
# Example with two version of PGC0, now _01 comes first
granules[(granules['cycle'] == '001') & (granules['pass'] == '229')]
# Out:
#                                                                                files  \
# 115  SWOT_L2_HR_RiverSP_Reach_001_229_GR_20230729T094809_20230729T094818_PGC0_02.shp
# 114  SWOT_L2_HR_RiverSP_Reach_001_229_GR_20230729T094809_20230729T094818_PGC0_01.shp
#
#     cycle pass version counter
# 115   001  229    PGC0      02
# 114   001  229    PGC0      01

# %%
# Keep only the best version of each granule
granules = granules.drop_duplicates(subset=['cycle', 'pass'], keep='first')

# %%
granules[(granules['cycle'] == '001') & (granules['pass'] == '229')]
# Out:
#                                                                                files  \
# 115  SWOT_L2_HR_RiverSP_Reach_001_229_GR_20230729T094809_20230729T094818_PGC0_02.shp
#
#     cycle pass version counter
# 115   001  229    PGC0      02

# %%
keep_files = list(granules['files'])

# %%
# NEED TO BE ABLE TO READ IN ALL FIVE FILE TYPES FOR EACH KEPT GRANULE'S
# FILENAME.

# %% [markdown]
# #### For PIXC

# %%
data_path = '/nas/cee-water/cjgleason/fiona/data_downloads/'

# %%
# Get all filenames in dir
files = []
for file in os.listdir(data_path):
    files.append(os.path.join(file))

# %%
# Make DataFrame of filenames
granules = pd.DataFrame({'files': files})

# %%
# Extract cycle, pass, tile, version, and counter
granules['cycle'] = granules['files'].str.slice(16, 19)
granules['pass'] = granules['files'].str.slice(20, 23)
granules['tile'] = granules['files'].str.slice(24, 28)
granules['version'] = granules['files'].str.slice(-10, -6)
granules['counter'] = granules['files'].str.slice(-5, -3)

# %%
granules
# Out:
#                                                                         files  \
# 0     SWOT_L2_HR_PIXC_474_013_237L_20230329T085422_20230329T085433_PGC0_01.nc
# 1     SWOT_L2_HR_PIXC_474_013_238L_20230329T085432_20230329T085443_PGC0_01.nc
# 2     SWOT_L2_HR_PIXC_475_013_237L_20230330T084500_20230330T084511_PGC0_01.nc
# 3     SWOT_L2_HR_PIXC_478_013_237L_20230402T081652_20230402T081703_PGC0_01.nc
# 4     SWOT_L2_HR_PIXC_475_013_238L_20230330T084510_20230330T084521_PGC0_01.nc
# ...                                                                       ...
# 2876  SWOT_L2_HR_PIXC_017_552_071L_20240708T181403_20240708T181414_PIC0_01.nc
# 2877  SWOT_L2_HR_PIXC_018_039_237L_20240711T073431_20240711T073442_PIC0_01.nc
# 2878  SWOT_L2_HR_PIXC_018_246_071R_20240718T163621_20240718T163632_PIC0_01.nc
# 2879  SWOT_L2_HR_PIXC_018_039_238L_20240711T073441_20240711T073452_PIC0_01.nc
# 2880  SWOT_L2_HR_PIXC_018_345_238R_20240722T055730_20240722T055741_PIC0_01.nc
#
#      cycle pass  tile version counter
# 0      474  013  237L    PGC0      01
# 1      474  013  238L    PGC0      01
# 2      475  013  237L    PGC0      01
# 3      478  013  237L    PGC0      01
# 4      475  013  238L    PGC0      01
# ...    ...  ...   ...     ...     ...
# 2876   017  552  071L    PIC0      01
# 2877   018  039  237L    PIC0      01
# 2878   018  246  071R    PIC0      01
# 2879   018  039  238L    PIC0      01
# 2880   018  345  238R    PIC0      01
#
# [2881 rows x 6 columns]

# %%
# View duplicates
dupe = granules[granules.duplicated(['cycle', 'pass', 'tile'])]

# %%
len(dupe)
# Out:
# 36

# %%
# Example with two versions of PGC0, _02 comes first
granules[(granules['cycle'] == '006') & (granules['pass'] == '552') & (granules['tile'] == '071L')]
# Out:
#                                                                        files  \
# 218  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PIC0_01.nc
# 219  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PGC0_01.nc
#
#     cycle pass  tile version counter
# 218   006  552  071L    PIC0      01
# 219   006  552  071L    PGC0      01

# %%
# Example with PGC0 vs PIC0, PIC0 comes first
granules[(granules['cycle'] == '006') & (granules['pass'] == '552')]
# Out:
#                                                                        files  \
# 218  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PIC0_01.nc
# 219  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PGC0_01.nc
# 220  SWOT_L2_HR_PIXC_006_552_072L_20231122T055822_20231122T055833_PIC0_01.nc
# 221  SWOT_L2_HR_PIXC_006_552_072L_20231122T055822_20231122T055833_PGC0_01.nc
#
#     cycle pass  tile version counter
# 218   006  552  071L    PIC0      01
# 219   006  552  071L    PGC0      01
# 220   006  552  072L    PIC0      01
# 221   006  552  072L    PGC0      01

# %%
# Sort the files
granules = granules.sort_values(by=['cycle', 'pass', 'tile', 'version', 'counter'],
                                ascending=[True, True, True, True, False])

# %%
# Example with two versions of PGC0, _02 comes first
granules[(granules['cycle'] == '006') & (granules['pass'] == '552') & (granules['tile'] == '071L')]
# Out:
#                                                                        files  \
# 219  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PGC0_01.nc
# 218  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PIC0_01.nc
#
#     cycle pass  tile version counter
# 219   006  552  071L    PGC0      01
# 218   006  552  071L    PIC0      01

# %%
# Example with PGC0 vs PIC0, now PGC0 comes first
granules[(granules['cycle'] == '006') & (granules['pass'] == '552')]
# Out:
#                                                                        files  \
# 219  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PGC0_01.nc
# 218  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PIC0_01.nc
# 221  SWOT_L2_HR_PIXC_006_552_072L_20231122T055822_20231122T055833_PGC0_01.nc
# 220  SWOT_L2_HR_PIXC_006_552_072L_20231122T055822_20231122T055833_PIC0_01.nc
#
#     cycle pass  tile version counter
# 219   006  552  071L    PGC0      01
# 218   006  552  071L    PIC0      01
# 221   006  552  072L    PGC0      01
# 220   006  552  072L    PIC0      01

# %%
# Keep only the best version of each granule
granules = granules.drop_duplicates(subset=['cycle', 'pass', 'tile'], keep='first')

# %%
# Example with two versions of PGC0, _02 comes first
granules[(granules['cycle'] == '006') & (granules['pass'] == '552') & (granules['tile'] == '071L')]
# Out:
#                                                                        files  \
# 219  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PGC0_01.nc
#
#     cycle pass  tile version counter
# 219   006  552  071L    PGC0      01

# %%
# Example with PGC0 vs PIC0, only PGC0 remains
granules[(granules['cycle'] == '006') & (granules['pass'] == '552')]
# Out:
#                                                                        files  \
# 219  SWOT_L2_HR_PIXC_006_552_071L_20231122T055812_20231122T055823_PGC0_01.nc
# 221  SWOT_L2_HR_PIXC_006_552_072L_20231122T055822_20231122T055833_PGC0_01.nc
#
#     cycle pass  tile version counter
# 219   006  552  071L    PGC0      01
# 221   006  552  072L    PGC0      01

# %%
# Get list of just the best/latest version of each granule
keep_files = list(granules['files'])

# %%
len(files)
# Out:
# 2881

# %%
len(keep_files)
# Out:
# 2845
