# %% [markdown]
# #### mergeFlowlines

# %%
import geopandas as gpd
import os
import pandas as pd
import time

# %%
look_up = pd.read_csv('/nas/cee-water/cjgleason/craig/CONUS_ephemeral/data/HUC4_lookup.csv')

# %%
datapath = '/nas/cee-water/cjgleason/craig/CONUS_ephemeral_data/'

# %%
codes_huc2 = ['01','02','03','04','05','06','07','08','09','10','11','12','13','14','15','16','17','18']

# %%
all_basins = gpd.GeoDataFrame()

# %%
fieldsF = ['GNIS_ID', 'GNIS_Name', 'LengthKM',  'FlowDir',
           'WBArea_Permanent_Identifier', 'FType', 'FCode',
           'NHDPlusID', 'VPUID', 'geometry']
fieldsVAA = ['NHDPlusID', 'StreamOrde', 'FromNode', 'ToNode',
            'LevelPathI', 'TerminalFl', 'TotDASqKm', 'VPUID']
fieldsEROMMA = ['NHDPlusID', 'QBMA', 'VPUID']

# %%
# Read in each set of flowlines in the HUC2 basin, merge on VAA
tic = time.time()

for i in range(len(codes_huc2)):
    # Get all HUC4 GBD paths for current HUC2 (exclude WBD)
    sub_paths = [fn for fn in os.listdir(os.path.join(datapath, 'HUC2_' + codes_huc2[i]))
                 if fn.startswith('NHD')]
    
    for j in sub_paths:
        path = os.path.join(datapath, 'HUC2_' + codes_huc2[i],
                            j, j + '.gdb')
        # print(path)
        
        # Flowlines
        new_basin = gpd.read_file(filename=path, layer='NHDFlowline',
                                  columns=fieldsF)
        # VAA
        vaa = gpd.read_file(filename=path, layer='NHDPlusFlowlineVAA',
                            columns=fieldsVAA)
        # Merge on VAA
        new_basin = new_basin.merge(vaa, on=['NHDPlusID', 'VPUID'])
        
        # EROMMA
        eromma = gpd.read_file(filename=path, layer='NHDPlusEROMMA',
                                columns=fieldsEROMMA)
        # Merge on EROMMA
        new_basin = new_basin.merge(eromma, on=['NHDPlusID', 'VPUID'])
        
        # Append new basin to existing
        all_basins = pd.concat([all_basins, new_basin])
        
print('{:.2f}s to make merged shapefile.'.format(time.time()-tic))

# %%
all_basins
# Out:
#        FCode  FType  FlowDir   GNIS_ID                       GNIS_Name  \
# 0      55800    558        1      None                            None
# 1      46006    460        1      None                            None
# 2      46003    460        1      None                            None
# 3      46006    460        1        -1                 Burntland Brook
# 4      46006    460        1        -1  North Branch Becaguimec Stream
# ...      ...    ...      ...       ...                             ...
# 97665  46007    460        1      None                            None
# 97666  46007    460        1      None                            None
# 97667  46006    460        1      None                            None
# 97668  46006    460        1  00272097               Little Kern River
# 97669  46007    460        1      None                            None
#
#        LengthKM     NHDPlusID VPUID             WBArea_Permanent_Identifier  \
# 0      1.678533  5.000100e+12  0101  {A44FF3D6-77AE-475F-ABF4-A69F85C427D6}
# 1      3.339840  5.000100e+12  0101                                    None
# 2      0.836389  5.000100e+12  0101                                    None
# 3      0.724000  5.000100e+12  0101                                    None
# 4      0.426000  5.000100e+12  0101                                    None
# ...         ...           ...   ...                                     ...
# 97665  0.069000  5.000100e+13  1803                                    None
# 97666  0.078000  5.000100e+13  1803                                    None
# 97667  0.100112  5.000100e+13  1803                                    None
# 97668  2.937799  5.000100e+13  1803                                    None
# 97669  2.497000  5.000100e+13  1803                                    None
#
#                                                 geometry      FromNode  \
# 0      MULTILINESTRING Z ((-68.58938 48.05766 0, -68....  5.000100e+12
# 1      MULTILINESTRING Z ((-67.8897 47.20717 0, -67.8...  5.000100e+12
# 2      MULTILINESTRING Z ((-70.32724 46.44595 0, -70....  5.000100e+12
# 3      MULTILINESTRING Z ((-67.3152 46.26263 0, -67.3...  5.000100e+12
# 4      MULTILINESTRING Z ((-67.26483 46.33892 0, -67....  5.000100e+12
# ...                                                  ...           ...
# 97665  MULTILINESTRING Z ((-119.27876 36.99176 0, -11...  5.000100e+13
# 97666  MULTILINESTRING Z ((-119.26894 36.99076 0, -11...  5.000100e+13
# 97667  MULTILINESTRING Z ((-118.20324 36.41839 0, -11...  5.000100e+13
# 97668  MULTILINESTRING Z ((-118.43785 36.18062 0, -11...  5.000100e+13
# 97669  MULTILINESTRING Z ((-119.01352 35.0163 0, -119...  5.000100e+13
#
#          LevelPathI  StreamOrde  TerminalFl        ToNode  TotDASqKm  \
# 0      5.000100e+12           2           0  5.000100e+12     9.3662
# 1      5.000100e+12           1           0  5.000100e+12     4.3692
# 2      5.000100e+12           2           0  5.000100e+12     1.9543
# 3      5.000100e+12           2           0  5.000100e+12    14.5836
# 4      5.000100e+12           3           0  5.000100e+12    41.0453
# ...             ...         ...         ...           ...        ...
# 97665  5.000100e+13           1           0  5.000100e+13     0.0018
# 97666  5.000100e+13           1           0  5.000100e+13     0.0025
# 97667  5.000100e+13           1           0  5.000100e+13     0.0147
# 97668  5.000100e+13           5           0  5.000100e+13   338.7869
# 97669  5.000100e+13           1           1  5.000100e+13     1.1907
#
#              QBMA
# 0        6.942256
# 1        2.581971
# 2        1.616468
# 3       10.966773
# 4       36.687272
# ...           ...
# 97665    0.000703
# 97666    0.000935
# 97667    0.003155
# 97668  223.982190
# 97669    0.013504
#
# [23425931 rows x 17 columns]

# %% [markdown]
# **Divisions**

# %%
# Read in shapefile for physiographic divisions
# https://www.sciencebase.gov/catalog/item/631405bbd34e36012efa304e
physio = gpd.read_file('/nas/cee-water/cjgleason/craig/CONUS_ephemeral_data/other_shapefiles/physio.shp')

# %%
physio
# Out:
#        AREA  PERIMETER  PHYSIODD_  PHYSIODD_I  FCODE FENCODE  \
# 0    40.121     36.938          2          72    122     12b
# 1    21.976     39.951          3          59    131     13a
# 2     2.706     18.014          4          33    241     24a
# 3     3.636      8.140          5          34    231     23a
# 4    30.059     28.208          6          48    190      19
# ..      ...        ...        ...         ...    ...     ...
# 496   0.001      0.123        498         496     33      3c
# 497   0.000      0.072        499         498     33      3c
# 498   0.002      0.231        500         499     33      3c
# 499   0.001      0.162        501         501     33      3c
# 500   0.001      0.187        502         500     33      3c
#
#                     DIVISION                  PROVINCE  \
# 0            INTERIOR PLAINS           CENTRAL LOWLAND
# 1            INTERIOR PLAINS              GREAT PLAINS
# 2    PACIFIC MOUNTAIN SYSTEM            PACIFIC BORDER
# 3    PACIFIC MOUNTAIN SYSTEM  CASCADE-SIERRA MOUNTAINS
# 4      ROCKY MOUNTAIN SYSTEM  NORTHERN ROCKY MOUNTAINS
# ..                       ...                       ...
# 496           ATLANTIC PLAIN             COASTAL PLAIN
# 497           ATLANTIC PLAIN             COASTAL PLAIN
# 498           ATLANTIC PLAIN             COASTAL PLAIN
# 499           ATLANTIC PLAIN             COASTAL PLAIN
# 500           ATLANTIC PLAIN             COASTAL PLAIN
#
#                          SECTION  PROVCODE  \
# 0                   WESTERN LAKE        12
# 1    MISSOURI PLATEAU, GLACIATED        13
# 2                   PUGET TROUGH        24
# 3     NORTHERN CASCADE MOUNTAINS        23
# 4                           None        19
# ..                           ...       ...
# 496                    FLORIDIAN         3
# 497                    FLORIDIAN         3
# 498                    FLORIDIAN         3
# 499                    FLORIDIAN         3
# 500                    FLORIDIAN         3
#
#                                               geometry
# 0    POLYGON ((-103.00201 49.00395, -102.94103 49.0...
# 1    POLYGON ((-113.55362 48.99719, -112.19278 48.9...
# 2    POLYGON ((-122.35828 47.59034, -122.33666 47.5...
# 3    POLYGON ((-122.14882 49.00173, -120.85696 48.9...
# 4    POLYGON ((-119.67419 49.00147, -118.84358 48.9...
# ..                                                 ...
# 496  POLYGON ((-81.42094 24.645, -81.46506 24.66677...
# 497  POLYGON ((-81.42094 24.645, -81.41373 24.67262...
# 498  POLYGON ((-81.70815 24.58081, -81.70338 24.599...
# 499  POLYGON ((-82.10853 24.56015, -82.10152 24.575...
# 500  POLYGON ((-81.81126 24.55392, -81.73983 24.581...
#
# [501 rows x 11 columns]

# %%
# Dissolve provinces by division
physio = physio.dissolve(by='DIVISION')

# %%
physio
# Out:
#                                                                   geometry  \
# DIVISION
# APPALACHIAN HIGHLANDS    MULTIPOLYGON (((-75.02058 40.10976, -75.05604 ...
# ATLANTIC PLAIN           MULTIPOLYGON (((-97.18027 26.07179, -97.2122 2...
# INTERIOR HIGHLANDS       POLYGON ((-91.96892 34.99696, -92.00708 34.942...
# INTERIOR PLAINS          MULTIPOLYGON (((-97.22617 32.50676, -97.24682 ...
# INTERMONTANE PLATEAUS    POLYGON ((-116.26199 33.20382, -116.22265 33.2...
# LAURENTIAN UPLAND        MULTIPOLYGON (((-92.08446 46.77362, -92.02456 ...
# PACIFIC MOUNTAIN SYSTEM  MULTIPOLYGON (((-121.96342 38.07818, -122.0020...
# ROCKY MOUNTAIN SYSTEM    POLYGON ((-106.29187 42.77171, -106.18233 42.7...
#
#                            AREA  PERIMETER  PHYSIODD_  PHYSIODD_I  FCODE  \
# DIVISION
# APPALACHIAN HIGHLANDS    11.837     36.376         37          57     92
# ATLANTIC PLAIN            0.104      3.401        159         167     31
# INTERIOR HIGHLANDS       11.628     15.892        246          22    141
# INTERIOR PLAINS          40.121     36.938          2          72    122
# INTERMONTANE PLATEAUS    13.383     21.026         25          56    201
# LAURENTIAN UPLAND        12.770     26.727         12          79     10
# PACIFIC MOUNTAIN SYSTEM   2.706     18.014          4          33    241
# ROCKY MOUNTAIN SYSTEM    30.059     28.208          6          48    190
#
#                         FENCODE                  PROVINCE  \
# DIVISION
# APPALACHIAN HIGHLANDS        9b               NEW ENGLAND
# ATLANTIC PLAIN               3a             COASTAL PLAIN
# INTERIOR HIGHLANDS          14a            OZARK PLATEAUS
# INTERIOR PLAINS             12b           CENTRAL LOWLAND
# INTERMONTANE PLATEAUS       20a          COLUMBIA PLATEAU
# LAURENTIAN UPLAND             1           SUPERIOR UPLAND
# PACIFIC MOUNTAIN SYSTEM     24a            PACIFIC BORDER
# ROCKY MOUNTAIN SYSTEM        19  NORTHERN ROCKY MOUNTAINS
#
#                                             SECTION  PROVCODE
# DIVISION
# APPALACHIAN HIGHLANDS            NEW ENGLAND UPLAND         9
# ATLANTIC PLAIN                              EMBAYED         3
# INTERIOR HIGHLANDS       SPRINGFIELD-SALEM PLATEAUS        14
# INTERIOR PLAINS                        WESTERN LAKE        12
# INTERMONTANE PLATEAUS           WALLA WALLA PLATEAU        20
# LAURENTIAN UPLAND                              None         1
# PACIFIC MOUNTAIN SYSTEM                PUGET TROUGH        24
# ROCKY MOUNTAIN SYSTEM                          None        19

# %%
physio = physio.to_crs(epsg=3857)

# %%
# Round the NHDPlusID (maybe not necessary, Craig's issue was from QGIS pre-pro)
all_basins.NHDPlusID = all_basins.NHDPlusID.round(0)

# %%
# Write out
all_basins.to_file('/nas/cee-water/cjgleason/fiona/narrow_rivers/data/nhd_conus_flow_vaa.gpkg', driver='GPKG')

# %%
# all_basins.plot()

# %% [markdown]
# #### calculateWidths

# %%
import geopandas as gpd

# %%
basins = gpd.read_file('/nas/cee-water/cjgleason/fiona/narrow_rivers/data/nhd_conus_flow_vaa.gpkg')

# %%
basins = basins.to_crs(epsg=3857)

# %%
subset = basins.iloc[0:5, :]

# %%
subset
# Out:
#    FCode  FType  FlowDir GNIS_ID                       GNIS_Name  LengthKM  \
# 0  55800    558        1    None                            None  1.678533
# 1  46006    460        1    None                            None  3.339840
# 2  46003    460        1    None                            None  0.836389
# 3  46006    460        1      -1                 Burntland Brook  0.724000
# 4  46006    460        1      -1  North Branch Becaguimec Stream  0.426000
#
#       NHDPlusID VPUID             WBArea_Permanent_Identifier      FromNode  \
# 0  5.000100e+12  0101  {A44FF3D6-77AE-475F-ABF4-A69F85C427D6}  5.000100e+12
# 1  5.000100e+12  0101                                    None  5.000100e+12
# 2  5.000100e+12  0101                                    None  5.000100e+12
# 3  5.000100e+12  0101                                    None  5.000100e+12
# 4  5.000100e+12  0101                                    None  5.000100e+12
#
#      LevelPathI  StreamOrde  TerminalFl        ToNode  TotDASqKm       QBMA  \
# 0  5.000100e+12           2           0  5.000100e+12     9.3662   6.942256
# 1  5.000100e+12           1           0  5.000100e+12     4.3692   2.581971
# 2  5.000100e+12           2           0  5.000100e+12     1.9543   1.616468
# 3  5.000100e+12           2           0  5.000100e+12    14.5836  10.966773
# 4  5.000100e+12           3           0  5.000100e+12    41.0453  36.687272
#
#                                             geometry
# 0  MULTILINESTRING Z ((-68.58938 48.05766 0, -68....
# 1  MULTILINESTRING Z ((-67.8897 47.20717 0, -67.8...
# 2  MULTILINESTRING Z ((-70.32724 46.44595 0, -70....
# 3  MULTILINESTRING Z ((-67.3152 46.26263 0, -67.3...
# 4  MULTILINESTRING Z ((-67.26483 46.33892 0, -67....

# %%
subset.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
test = gpd.sjoin(gdf_wm, nhd_wm, how='inner', predicate='within')

# %%
# Prep the data (per the recommendations of Craig Brinkerhoff)

# %%
# Keep only reaches that are stream types or artificial path
all_basins = all_basins.loc[((all_basins.FCode == 46000) |
                             (all_basins.FCode == 46003) |
                             (all_basins.FCode == 46006) |
                             (all_basins.FCode == 46007) |
                             (all_basins.FCode == 55800))]

# %%
# Keep only flowlines that are not in lakes
## REMOVES THE CONNECTICUT
# all_basins =
# all_basins.loc[all_basins.WBArea_Permanent_Identifier.isnull()]

# %%
# Keep reaches that are not terminal paths
all_basins = all_basins[all_basins.TerminalFl == 0]

# %%
all_basins.shape
# Out:
# (22261957, 17)

# %%
# Keep only reaches with non-zero discharge
all_basins = all_basins.loc[all_basins.QBMA > 0]

# %%
all_basins.shape
# Out:
# (22029705, 17)

# %%
# Keep only reaches with non-zero stream order
all_basins = all_basins.loc[all_basins.StreamOrde > 0]

# %%
all_basins.shape
# Out:
# (22029705, 17)
