# %%
## NOT NEEDED, DIDN'T REPAIR FULLY, USING INTERSECTS INSTEAD

# %%
sys(umask:002)
# Out:
# Error in sys(umask:2): could not find function "sys"
# Traceback:

# %%
library(sf)
# Out:
# Linking to GEOS 3.11.2, GDAL 3.7.0, PROJ 9.2.1; sf_use_s2() is TRUE

# %%
data_path = '/nas/cee-water/cjgleason/craig/CONUS_ephemeral_data/other_shapefiles/physio.shp'
save_path = '/nas/cee-water/cjgleason/fiona/narrow_rivers_PIXC/data'

# %%
file.path(save_path, 'physio_repaired.shp')
# Out:
# [1] "/nas/cee-water/cjgleason/fiona/narrow_rivers_PIXC/data/physio_repaired.shp"

# %%
physio <- read_sf(dsn=data_path)

# %%
plot(st_geometry(physio))
# Out:
# plot without title

# %%
physio <- sf::st_make_valid(physio)

# %%
sf::st_write(obj=physio, dsn=file.path(save_path, 'physio_repaired.shp'), driver='ESRI Shapefile')
# Out:
# Writing layer `physio_repaired' to data source
#   `/nas/cee-water/cjgleason/fiona/narrow_rivers_PIXC/data/physio_repaired.shp' using driver `ESRI Shapefile'
# Writing 501 features with 10 fields and geometry type Multi Polygon.
