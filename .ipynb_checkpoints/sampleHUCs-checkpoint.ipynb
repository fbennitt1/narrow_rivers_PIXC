# %%
from datetime import datetime
import earthaccess
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
mdata_path = '/nas/cee-water/cjgleason/fiona/narrow_rivers_PIXC/data/'

# %%
# Define dtypes for lookup tables to preserve leading zeros
dtype_dic= {'HUC4': str, 'HUC2': str, 'toBasin': str, 'level': str}

# Read in HUC lookup table
lookup = pd.read_csv(os.path.join(mdata_path, 'HUC4_lookup_no_great_lakes.csv'), dtype=dtype_dic)

# %%
lookup
# Out:
#      slurm_index  HUC4 HUC2 toBasin level
# 0              0  0101   01     NaN     0
# 1              1  0102   01    0105     0
# 2              2  0106   01     NaN     0
# 3              3  0107   01     NaN     0
# 4              4  0108   01     NaN     0
# ..           ...   ...  ...     ...   ...
# 200          200  1027   10    1030     1
# 201          201  1204   12     NaN     1
# 202          202  0508   05    0509     0
# 203          203  0513   05    0514     0
# 204          204  0604   05    0514     3
#
# [205 rows x 5 columns]

# %%
lookup.groupby('HUC2').sample(n=1)
# Out:
#      slurm_index  HUC4 HUC2 toBasin level
# 2              2  0106   01     NaN     0
# 10            10  0206   02    0208     1
# 20            20  0310   03     NaN     0
# 194          194  0408   04    0424     0
# 202          202  0508   05    0509     0
# 37            37  0603   06    0604     2
# 40            40  0704   07    0706     2
# 52            52  0807   08    0809    17
# 55            55  0903   09     NaN     0
# 144          144  1012   10    1013     0
# 72            72  1103   11    1106     1
# 201          201  1204   12     NaN     1
# 83            83  1301   13    1302     0
# 93            93  1403   14    1407     2
# 160          160  1507   15    1503     2
# 101          101  1604   16    1605     0
# 109          109  1711   17     NaN     0
# 166          166  1804   18     NaN     1

# %%
data_path = '/nas/cee-water/cjgleason/craig/CONUS_ephemeral_data/'

# %%
# Slurm index
index = 2

# Get current HUC2 and HUC4 IDs
huc2 = 'HUC2_' + lookup.loc[index,'HUC4'][0:2]
huc2_num = lookup.loc[index,'HUC4'][0:2]
huc4 = 'NHDPLUS_H_' + lookup.loc[index,'HUC4'] + '_HU4_GDB'
huc4_num = lookup.loc[index,'HUC4']

# %%
huc4_num
# Out:
# '0106'

# %%
# Set data filepath
file_path = os.path.join(data_path, huc2, 'WBD_' + huc2_num + '_HU2_Shape',
                         'Shape', 'WBDHU4.shp')

# %%
## Read in prepped NHD flowlines
# features = ['NHDPlusID', 'GNIS_Name', 'LengthKM', 'WidthM', 'Bin', 'geometry']
basin = gpd.read_file(filename=file_path,
                      # columns=features,
                      engine='pyogrio')

# %%
basin = basin.to_crs(epsg=3857)

# %%
basin[basin['huc4'] == hu4_num]
# Out:
#    objectid                                   tnmid metasource sourcedata  \
# 3         4  {04E4A162-3BB8-4F87-897B-A00E49DE7F8D}       None       None
#
#   sourceorig sourcefeat   loaddate referenceg   areaacres  areasqkm    states  \
# 3       None       None 2020-12-16       None  3105641.36   12568.1  MA,ME,NH
#
#    huc4  name  shape_Leng  shape_Area  \
# 3  0106  Saco    9.199596    1.401944
#
#                                             geometry
# 3  POLYGON ((-70.8225 44.39, -70.82243 44.38992, ...

# %%
center = basin[basin['huc4'] == hu4_num].centroid

# %%
fig, ax = plt.subplots(figsize=(12,8))
basin.plot(ax=ax)
center.plot(ax=ax, color='r')
# Out:
# <Axes: >

# %%
center_box = center.buffer(10000, cap_style = 3).to_crs(epsg=4269)

# %%
# Get bounds of buffered polygon
bounds = list(zip(center_box.bounds['minx'], center_box.bounds['miny'],
                  center_box.bounds['maxx'], center_box.bounds['maxy']))[0]

# %%
# Find SWOT granules
pixc_results = earthaccess.search_data(short_name = 'SWOT_L2_HR_PIXC_2.0',
                                       temporal = ('2024-08-01 00:00:00',
                                                    str(datetime.now())),
                                       bounding_box = bounds)

# %%
pixc_results
# Out:
# [Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.30336972775632, 'SouthBoundingCoordinate': 43.02870544574289, 'EastBoundingCoordinate': -70.29889216655403, 'NorthBoundingCoordinate': 43.788390215962814}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 35, 'Tiles': ['231R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-01T00:52:59.814Z', 'BeginningDateTime': '2024-08-01T00:52:48.720Z'}}
#  Size(MB): 665.9755954742432
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_035_231R_20240801T005248_20240801T005259_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.30336972775632, 'SouthBoundingCoordinate': 43.02870544574289, 'EastBoundingCoordinate': -70.29889216655403, 'NorthBoundingCoordinate': 43.788390215962814}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 35, 'Tiles': ['231R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-01T00:52:59.814Z', 'BeginningDateTime': '2024-08-01T00:52:48.720Z'}}
#  Size(MB): 669.4693193435669
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_035_231R_20240801T005248_20240801T005259_PIC0_02.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.96011497310326, 'SouthBoundingCoordinate': 43.58419692952484, 'EastBoundingCoordinate': -70.07919906442908, 'NorthBoundingCoordinate': 44.35711052380369}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 35, 'Tiles': ['232R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-01T00:53:09.815Z', 'BeginningDateTime': '2024-08-01T00:52:58.723Z'}}
#  Size(MB): 508.3982925415039
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_035_232R_20240801T005258_20240801T005309_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.96011497310326, 'SouthBoundingCoordinate': 43.58419692952484, 'EastBoundingCoordinate': -70.07919906442908, 'NorthBoundingCoordinate': 44.35711052380369}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 35, 'Tiles': ['232R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-01T00:53:09.815Z', 'BeginningDateTime': '2024-08-01T00:52:58.723Z'}}
#  Size(MB): 512.1687965393066
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_035_232R_20240801T005258_20240801T005309_PIC0_02.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.75525502598799, 'SouthBoundingCoordinate': 43.02665288365761, 'EastBoundingCoordinate': -70.78570645353034, 'NorthBoundingCoordinate': 43.73793013274452}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 270, 'Tiles': ['078R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-09T09:57:30.680Z', 'BeginningDateTime': '2024-08-09T09:57:19.591Z'}}
#  Size(MB): 545.2345247268677
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_270_078R_20240809T095719_20240809T095730_PIC0_02.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.91979818084849, 'SouthBoundingCoordinate': 43.18817900049138, 'EastBoundingCoordinate': -69.91121008285319, 'NorthBoundingCoordinate': 43.94683639506781}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 270, 'Tiles': ['078L']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-09T09:57:30.685Z', 'BeginningDateTime': '2024-08-09T09:57:19.594Z'}}
#  Size(MB): 850.1376886367798
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_270_078L_20240809T095719_20240809T095730_PIC0_02.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.74172082845143, 'SouthBoundingCoordinate': 43.58567251042592, 'EastBoundingCoordinate': -69.69580394227995, 'NorthBoundingCoordinate': 44.34229933494084}]}, 'Track': {'Cycle': 19, 'Passes': [{'Pass': 548, 'Tiles': ['077R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-19T08:19:36.799Z', 'BeginningDateTime': '2024-08-19T08:19:25.708Z'}}
#  Size(MB): 573.414155960083
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_019_548_077R_20240819T081925_20240819T081936_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.30352008687896, 'SouthBoundingCoordinate': 43.028898715153275, 'EastBoundingCoordinate': -70.29962287867346, 'NorthBoundingCoordinate': 43.78839159570806}]}, 'Track': {'Cycle': 20, 'Passes': [{'Pass': 35, 'Tiles': ['231R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-21T21:38:03.995Z', 'BeginningDateTime': '2024-08-21T21:37:52.899Z'}}
#  Size(MB): 674.8348541259766
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_020_035_231R_20240821T213752_20240821T213803_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.95965347486708, 'SouthBoundingCoordinate': 43.58437545362197, 'EastBoundingCoordinate': -70.0798664488301, 'NorthBoundingCoordinate': 44.3572774948386}]}, 'Track': {'Cycle': 20, 'Passes': [{'Pass': 35, 'Tiles': ['232R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-21T21:38:13.999Z', 'BeginningDateTime': '2024-08-21T21:38:02.904Z'}}
#  Size(MB): 525.2954607009888
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_020_035_232R_20240821T213802_20240821T213813_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.75335301778364, 'SouthBoundingCoordinate': 43.02695779863306, 'EastBoundingCoordinate': -70.78592936916687, 'NorthBoundingCoordinate': 43.737947277753165}]}, 'Track': {'Cycle': 20, 'Passes': [{'Pass': 270, 'Tiles': ['078R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-30T06:42:35.253Z', 'BeginningDateTime': '2024-08-30T06:42:24.161Z'}}
#  Size(MB): 462.8208475112915
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_020_270_078R_20240830T064224_20240830T064235_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.91975563553541, 'SouthBoundingCoordinate': 43.18816131925015, 'EastBoundingCoordinate': -69.91022381938791, 'NorthBoundingCoordinate': 43.94696193244874}]}, 'Track': {'Cycle': 20, 'Passes': [{'Pass': 270, 'Tiles': ['078L']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-30T06:42:35.258Z', 'BeginningDateTime': '2024-08-30T06:42:24.165Z'}}
#  Size(MB): 818.9490766525269
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_020_270_078L_20240830T064224_20240830T064235_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.90062252811742, 'SouthBoundingCoordinate': 43.1836623645377, 'EastBoundingCoordinate': -69.93439656875307, 'NorthBoundingCoordinate': 43.94899990166047}]}, 'Track': {'Cycle': 20, 'Passes': [{'Pass': 313, 'Tiles': ['231L']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-08-31T20:00:22.340Z', 'BeginningDateTime': '2024-08-31T20:00:11.248Z'}}
#  Size(MB): 605.9843788146973
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_020_313_231L_20240831T200011_20240831T200022_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.74126969371787, 'SouthBoundingCoordinate': 43.58597910047142, 'EastBoundingCoordinate': -69.68775745075345, 'NorthBoundingCoordinate': 44.34191508901778}]}, 'Track': {'Cycle': 20, 'Passes': [{'Pass': 548, 'Tiles': ['077R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-09-09T05:04:42.635Z', 'BeginningDateTime': '2024-09-09T05:04:31.546Z'}}
#  Size(MB): 582.948410987854
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_020_548_077R_20240909T050431_20240909T050442_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.30338730309211, 'SouthBoundingCoordinate': 43.0298240015146, 'EastBoundingCoordinate': -70.30398405355214, 'NorthBoundingCoordinate': 43.78837260163505}]}, 'Track': {'Cycle': 21, 'Passes': [{'Pass': 35, 'Tiles': ['231R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-09-11T18:23:10.125Z', 'BeginningDateTime': '2024-09-11T18:22:59.031Z'}}
#  Size(MB): 653.968020439148
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_021_035_231R_20240911T182259_20240911T182310_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.96015358477484, 'SouthBoundingCoordinate': 43.58526579701207, 'EastBoundingCoordinate': -70.08377106335263, 'NorthBoundingCoordinate': 44.357891894664164}]}, 'Track': {'Cycle': 21, 'Passes': [{'Pass': 35, 'Tiles': ['232R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-09-11T18:23:20.126Z', 'BeginningDateTime': '2024-09-11T18:23:09.034Z'}}
#  Size(MB): 494.19201374053955
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_021_035_232R_20240911T182309_20240911T182320_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -71.7523111080568, 'SouthBoundingCoordinate': 43.02714881606081, 'EastBoundingCoordinate': -70.78563379441374, 'NorthBoundingCoordinate': 43.73789464895277}]}, 'Track': {'Cycle': 21, 'Passes': [{'Pass': 270, 'Tiles': ['078R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-09-20T03:27:41.775Z', 'BeginningDateTime': '2024-09-20T03:27:30.680Z'}}
#  Size(MB): 463.3945121765137
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_021_270_078R_20240920T032730_20240920T032741_PIC0_01.nc'],
#  Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_PIXC_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -70.91948629682327, 'SouthBoundingCoordinate': 43.18820477818053, 'EastBoundingCoordinate': -69.90836219086259, 'NorthBoundingCoordinate': 43.94724177446555}]}, 'Track': {'Cycle': 21, 'Passes': [{'Pass': 270, 'Tiles': ['078L']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-09-20T03:27:41.778Z', 'BeginningDateTime': '2024-09-20T03:27:30.686Z'}}
#  Size(MB): 837.2317218780518
#  Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_PIXC_2.0/SWOT_L2_HR_PIXC_021_270_078L_20240920T032730_20240920T032741_PIC0_01.nc']]
